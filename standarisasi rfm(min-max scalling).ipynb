# %%
rfm_scalled = MinMaxScaler().fit_transform(rfm)

# %%
print(rfm_scalled)
# Out:
# [[0.87131367 0.00404858 0.01510917]
#  [0.00268097 0.0242915  0.03029717]
#  [0.19839142 0.01214575 0.02144246]
#  ...
#  [0.01876676 0.00809717 0.01573149]
#  [0.0080429  0.06072874 0.02249131]
#  [0.11260054 0.00809717 0.02158356]]

# %%
data_clean = df[df['UnitPrice'] > 0]

# %%
rfm = rfm.reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(rfm['Recency'], kde=True)
plt.show()
